# %%
from sqlalchemy import create_engine
import pandas as pd
import requests

# %%
connection_string = "postgres:sealab2021@dvgroup1.c0yvlavqskus.us-west-2.rds.amazonaws.com:5432/project2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['trails', 'routes', 'dispensaries']

# %%
mtn_api = '200227251-dff824783300bfdde3f3714b65feede7'
hike_api = '200227251-52bbf40f14de65bb8de3f88b82402869'

# %%
cities = pd.read_csv('static/js/latlong_list_forAPI.csv')
cities
# Out:
#                                       names  latitude  longitude  \
# 0                                 Sand Rock    34.180    -85.817
# 1                                 Jamestown    34.411    -85.574
# 2                            Palisades Park    33.989    -86.458
# 3    Anchorage & South Central Ice Climbing    61.213   -149.867
# 4                      Denali National Park    63.065   -151.172
# ..                                      ...       ...        ...
# 112                                Vedauwoo    41.185   -105.378
# 113               Grand Teton National Park    43.741   -110.803
# 114                        Wind River Range    42.755   -109.204
# 115                            Sinks Canyon    42.739   -108.830
# 116                   Rock Springs Buttress    43.588   -110.870
#
#                                   alt_names
# 0                                 Sand Rock
# 1                                 Jamestown
# 2                            Palisades Park
# 3    Anchorage & South Central Ice Climbing
# 4                      Denali National Park
# ..                                      ...
# 112                                Vedauwoo
# 113               Grand Teton National Park
# 114                        Wind River Range
# 115                            Sinks Canyon
# 116                   Rock Springs Buttress
#
# [117 rows x 4 columns]

# %%
cities_list = []
for ea in range(0,len(cities)):
#     print(cities['name'][ea])
    cities_list.append(
        {
            "name": cities['names'][ea],
            "lat": cities['latitude'][ea],
            "lon": cities['longitude'][ea],
            "alt_name": cities['alt_names'][ea]})
cities_list
# Out:
# [{'name': 'Sand Rock',
#   'lat': 34.18,
#   'lon': -85.81700000000001,
#   'alt_name': 'Sand Rock'},
#  {'name': 'Jamestown', 'lat': 34.411, 'lon': -85.574, 'alt_name': 'Jamestown'},
#  {'name': 'Palisades Park',
#   'lat': 33.989000000000004,
#   'lon': -86.458,
#   'alt_name': 'Palisades Park'},
#  {'name': 'Anchorage & South Central Ice Climbing',
#   'lat': 61.213,
#   'lon': -149.86700000000002,
#   'alt_name': 'Anchorage & South Central Ice Climbing'},
#  {'name': 'Denali National Park',
#   'lat': 63.065,
#   'lon': -151.172,
#   'alt_name': 'Denali National Park'},
#  {'name': 'Seward Highway',
#   'lat': 61.058,
#   'lon': -149.798,
#   'alt_name': 'Seward Highway'},
#  {'name': 'Cochise Stronghold',
#   'lat': 31.921,
#   'lon': -109.98700000000001,
#   'alt_name': 'Cochise Stronghold'},
#  {'name': 'Sedona Area',
#   'lat': 34.868,
#   'lon': -111.762,
#   'alt_name': 'Sedona Area'},
#  {'name': 'Paradise Forks',
#   'lat': 35.138000000000005,
#   'lon': -112.024,
#   'alt_name': 'Paradise Forks'},
#  {'name': 'Winslow Wall',
#   'lat': 34.942,
#   'lon': -110.663,
#   'alt_name': 'Winslow Wall'},
#  {'name': 'Mount Lemmon (Santa Catalina Mountains)',
#   'lat': 32.446999999999996,
#   'lon': -110.79,
#   'alt_name': 'Mount Lemmon (Santa Catalina Mountains)'},
#  {'name': 'Horseshoe Canyon Ranch',
#   'lat': 36.012,
#   'lon': -93.292,
#   'alt_name': 'Horseshoe Canyon Ranch'},
#  {'name': "Sam's Throne & Surroundings",
#   'lat': 35.858000000000004,
#   'lon': -93.044,
#   'alt_name': "Sam's Throne & Surroundings"},
#  {'name': 'Joshua Tree National Park',
#   'lat': 34.012,
#   'lon': -116.16799999999999,
#   'alt_name': 'Joshua Tree National Park'},
#  {'name': "Lover's Leap",
#   'lat': 38.799,
#   'lon': -120.141,
#   'alt_name': "Lover's Leap"},
#  {'name': 'Tahquitz & Suicide Rocks',
#   'lat': 33.760999999999996,
#   'lon': -116.679,
#   'alt_name': 'Tahquitz & Suicide Rocks'},
#  {'name': 'High Sierra',
#   'lat': 37.275,
#   'lon': -118.677,
#   'alt_name': 'High Sierra'},
#  {'name': 'Sierra Eastside',
#   'lat': 37.335,
#   'lon': -118.499,
#   'alt_name': 'Sierra Eastside'},
#  {'name': 'Lake Tahoe',
#   'lat': 39.109,
#   'lon': -120.23700000000001,
#   'alt_name': 'Lake Tahoe'},
#  {'name': 'Yosemite National Park',
#   'lat': 37.74,
#   'lon': -119.573,
#   'alt_name': 'Yosemite National Park'},
#  {'name': 'The Needles / Kern River',
#   'lat': 36.029,
#   'lon': -118.47,
#   'alt_name': 'The Needles Kern River'},
#  {'name': 'Owens River Gorge',
#   'lat': 37.446,
#   'lon': -118.572,
#   'alt_name': 'Owens River Gorge'},
#  {'name': 'Western Sierra',
#   'lat': 35.967,
#   'lon': -118.484,
#   'alt_name': 'Western Sierra'},
#  {'name': 'Boulder Canyon',
#   'lat': 40.001999999999995,
#   'lon': -105.41,
#   'alt_name': 'Boulder Canyon'},
#  {'name': 'Lumpy Ridge',
#   'lat': 40.403,
#   'lon': -105.51799999999999,
#   'alt_name': 'Lumpy Ridge'},
#  {'name': 'Eldorado Canyon SP',
#   'lat': 39.931999999999995,
#   'lon': -105.281,
#   'alt_name': 'Eldorado Canyon SP'},
#  {'name': 'Shelf Road',
#   'lat': 38.63,
#   'lon': -105.223,
#   'alt_name': 'Shelf Road'},
#  {'name': 'Rifle Mountain Park',
#   'lat': 39.716,
#   'lon': -107.691,
#   'alt_name': 'Rifle Mountain Park'},
#  {'name': 'RMNP  Rock',
#   'lat': 40.375,
#   'lon': -105.616,
#   'alt_name': 'RMNP  Rock'},
#  {'name': 'Alpine Rock',
#   'lat': 40.257,
#   'lon': -105.65700000000001,
#   'alt_name': 'Alpine Rock'},
#  {'name': 'Flatirons',
#   'lat': 39.983000000000004,
#   'lon': -105.289,
#   'alt_name': 'Flatirons'},
#  {'name': 'South Platte',
#   'lat': 39.417,
#   'lon': -105.469,
#   'alt_name': 'South Platte'},
#  {'name': 'Grand Junction Area',
#   'lat': 39.080999999999996,
#   'lon': -108.522,
#   'alt_name': 'Grand Junction Area'},
#  {'name': 'Gunnison', 'lat': 38.545, 'lon': -106.928, 'alt_name': 'Gunnison'},
#  {'name': 'CO Ice & Mixed',
#   'lat': 38.994,
#   'lon': -105.93,
#   'alt_name': 'CO Ice & Mixed'},
#  {'name': 'Central Valley',
#   'lat': 41.63,
#   'lon': -72.81,
#   'alt_name': 'Central Valley'},
#  {'name': 'CT Bouldering',
#   'lat': 41.364,
#   'lon': -72.564,
#   'alt_name': 'CT Bouldering'},
#  {'name': 'Lost Wall',
#   'lat': 34.667,
#   'lon': -85.37100000000001,
#   'alt_name': 'Lost Wall'},
#  {'name': 'Mount Yonah',
#   'lat': 34.637,
#   'lon': -83.714,
#   'alt_name': 'Mount Yonah'},
#  {'name': "Mokule'ia Wall",
#   'lat': 21.574,
#   'lon': -158.23,
#   'alt_name': "Mokule'ia Wall"},
#  {'name': 'City of Rocks',
#   'lat': 42.078,
#   'lon': -113.72399999999999,
#   'alt_name': 'City of Rocks'},
#  {'name': 'Castle Rocks',
#   'lat': 42.135,
#   'lon': -113.67,
#   'alt_name': 'Castle Rocks'},
#  {'name': 'Massacre Rocks',
#   'lat': 42.675,
#   'lon': -112.99799999999999,
#   'alt_name': 'Massacre Rocks'},
#  {'name': 'The Sawtooth Range',
#   'lat': 44.148999999999994,
#   'lon': -114.91799999999999,
#   'alt_name': 'The Sawtooth Range'},
#  {'name': 'The Fins', 'lat': 43.731, 'lon': -113.084, 'alt_name': 'The Fins'},
#  {'name': 'Jackson Falls',
#   'lat': 37.507,
#   'lon': -88.682,
#   'alt_name': 'Jackson Falls'},
#  {'name': 'Giant City State Park',
#   'lat': 37.598,
#   'lon': -89.18799999999999,
#   'alt_name': 'Giant City State Park'},
#  {'name': 'The Holy Boulders',
#   'lat': 37.618,
#   'lon': -89.415,
#   'alt_name': 'The Holy Boulders'},
#  {'name': 'Red River Gorge',
#   'lat': 37.455999999999996,
#   'lon': -83.794,
#   'alt_name': 'Red River Gorge'},
#  {'name': 'Acadia National Park',
#   'lat': 44.34,
#   'lon': -68.258,
#   'alt_name': 'Acadia National Park'},
#  {'name': 'Munising', 'lat': 46.41, 'lon': -86.65, 'alt_name': 'Munising'},
#  {'name': 'HE MNI CAN / Barn Bluff (Red Wing)',
#   'lat': 44.57,
#   'lon': -92.52600000000001,
#   'alt_name': 'HE MNI CAN Barn Bluff (Red Wing)'},
#  {'name': 'Gallatin Canyon',
#   'lat': 45.407,
#   'lon': -111.225,
#   'alt_name': 'Gallatin Canyon'},
#  {'name': 'Red Rock', 'lat': 36.131, 'lon': -115.425, 'alt_name': 'Red Rock'},
#  {'name': 'Mount Charleston',
#   'lat': 36.272,
#   'lon': -115.695,
#   'alt_name': 'Mount Charleston'},
#  {'name': 'Rumney', 'lat': 43.802, 'lon': -71.837, 'alt_name': 'Rumney'},
#  {'name': 'Cathedral Ledge',
#   'lat': 44.06399999999999,
#   'lon': -71.166,
#   'alt_name': 'Cathedral Ledge'},
#  {'name': 'Whitehorse Ledge',
#   'lat': 44.055,
#   'lon': -71.167,
#   'alt_name': 'Whitehorse Ledge'},
#  {'name': 'Pawtuckaway',
#   'lat': 43.083999999999996,
#   'lon': -71.175,
#   'alt_name': 'Pawtuckaway'},
#  {'name': 'NH Ice and Mixed',
#   'lat': 44.037,
#   'lon': -71.119,
#   'alt_name': 'NH Ice and Mixed'},
#  {'name': 'Cannon Cliff',
#   'lat': 44.159,
#   'lon': -71.685,
#   'alt_name': 'Cannon Cliff'},
#  {'name': 'Sundown Ledge',
#   'lat': 44.007,
#   'lon': -71.232,
#   'alt_name': 'Sundown Ledge'},
#  {'name': 'Sandia Mountains',
#   'lat': 35.211,
#   'lon': -106.45,
#   'alt_name': 'Sandia Mountains'},
#  {'name': 'El Rito', 'lat': 36.393, 'lon': -106.196, 'alt_name': 'El Rito'},
#  {'name': 'Organ Mountains',
#   'lat': 32.35,
#   'lon': -106.566,
#   'alt_name': 'Organ Mountains'},
#  {'name': 'Enchanted Tower',
#   'lat': 34.23,
#   'lon': -107.917,
#   'alt_name': 'Enchanted Tower'},
#  {'name': 'Taos Area',
#   'lat': 36.406,
#   'lon': -105.574,
#   'alt_name': 'Taos Area'},
#  {'name': 'The Gunks', 'lat': 41.744, 'lon': -74.197, 'alt_name': 'The Gunks'},
#  {'name': 'Adirondacks',
#   'lat': 43.938,
#   'lon': -74.378,
#   'alt_name': 'Adirondacks'},
#  {'name': 'Linville Gorge',
#   'lat': 35.887,
#   'lon': -81.885,
#   'alt_name': 'Linville Gorge'},
#  {'name': 'Looking Glass Rock',
#   'lat': 35.295,
#   'lon': -82.788,
#   'alt_name': 'Looking Glass Rock'},
#  {'name': 'Stone Mountain',
#   'lat': 36.391999999999996,
#   'lon': -81.047,
#   'alt_name': 'Stone Mountain'},
#  {'name': 'Laurel Knob',
#   'lat': 35.15,
#   'lon': -83.056,
#   'alt_name': 'Laurel Knob'},
#  {'name': 'Rumbling Bald',
#   'lat': 35.449,
#   'lon': -82.214,
#   'alt_name': 'Rumbling Bald'},
#  {'name': "Moore's Wall",
#   'lat': 36.398,
#   'lon': -80.292,
#   'alt_name': "Moore's Wall"},
#  {'name': 'Quartz Mountain',
#   'lat': 34.898,
#   'lon': -99.334,
#   'alt_name': 'Quartz Mountain'},
#  {'name': 'Wichita Mountains Wildlife Refuge',
#   'lat': 34.711,
#   'lon': -98.62299999999999,
#   'alt_name': 'Wichita Mountains Wildlife Refuge'},
#  {'name': 'Smith Rock',
#   'lat': 44.368,
#   'lon': -121.139,
#   'alt_name': 'Smith Rock'},
#  {'name': 'Mt. Hood',
#   'lat': 45.373000000000005,
#   'lon': -121.696,
#   'alt_name': 'Mt. Hood'},
#  {'name': 'Birdsboro Quarry',
#   'lat': 40.254,
#   'lon': -75.814,
#   'alt_name': 'Birdsboro Quarry'},
#  {'name': 'Safe Harbor',
#   'lat': 39.935,
#   'lon': -76.385,
#   'alt_name': 'Safe Harbor'},
#  {'name': 'Spearfish Canyon',
#   'lat': 44.458,
#   'lon': -103.859,
#   'alt_name': 'Spearfish Canyon'},
#  {'name': 'Custer State Park',
#   'lat': 43.843999999999994,
#   'lon': -103.56299999999999,
#   'alt_name': 'Custer State Park'},
#  {'name': 'The Tennessee Wall',
#   'lat': 35.071999999999996,
#   'lon': -85.40299999999999,
#   'alt_name': 'The Tennessee Wall'},
#  {'name': 'Foster Falls',
#   'lat': 35.181999999999995,
#   'lon': -85.67399999999999,
#   'alt_name': 'Foster Falls'},
#  {'name': 'Sunset Park',
#   'lat': 34.999,
#   'lon': -85.355,
#   'alt_name': 'Sunset Park'},
#  {'name': 'Hueco Tanks',
#   'lat': 31.916999999999998,
#   'lon': -106.04299999999999,
#   'alt_name': 'Hueco Tanks'},
#  {'name': 'Enchanted Rock State Natural Area',
#   'lat': 30.503,
#   'lon': -98.821,
#   'alt_name': 'Enchanted Rock State Natural Area'},
#  {'name': 'Indian Creek',
#   'lat': 38.025999999999996,
#   'lon': -109.54,
#   'alt_name': 'Indian Creek'},
#  {'name': 'Castle Valley',
#   'lat': 38.684,
#   'lon': -109.42299999999999,
#   'alt_name': 'Castle Valley'},
#  {'name': 'Fisher Towers',
#   'lat': 38.724000000000004,
#   'lon': -109.30799999999999,
#   'alt_name': 'Fisher Towers'},
#  {'name': 'Zion National Park',
#   'lat': 37.259,
#   'lon': -112.973,
#   'alt_name': 'Zion National Park'},
#  {'name': 'American Fork Canyon',
#   'lat': 40.431999999999995,
#   'lon': -111.751,
#   'alt_name': 'American Fork Canyon'},
#  {'name': 'Little Cottonwood Canyon',
#   'lat': 40.573,
#   'lon': -111.777,
#   'alt_name': 'Little Cottonwood Canyon'},
#  {'name': 'Big Cottonwood Canyon',
#   'lat': 40.619,
#   'lon': -111.789,
#   'alt_name': 'Big Cottonwood Canyon'},
#  {'name': 'Maple Canyon',
#   'lat': 39.556,
#   'lon': -111.68700000000001,
#   'alt_name': 'Maple Canyon'},
#  {'name': 'San Rafael Swell',
#   'lat': 38.853,
#   'lon': -110.70100000000001,
#   'alt_name': 'San Rafael Swell'},
#  {'name': "Joe's Valley",
#   'lat': 39.277,
#   'lon': -111.17399999999999,
#   'alt_name': "Joe's Valley"},
#  {'name': 'Lake Willoughby',
#   'lat': 44.742,
#   'lon': -72.048,
#   'alt_name': 'Lake Willoughby'},
#  {'name': 'VT Ice and Mixed',
#   'lat': 44.226000000000006,
#   'lon': -72.587,
#   'alt_name': 'VT Ice and Mixed'},
#  {'name': 'Grayson Highlands State Park',
#   'lat': 36.611999999999995,
#   'lon': -81.491,
#   'alt_name': 'Grayson Highlands State Park'},
#  {'name': 'Exit 32 / Little Si',
#   'lat': 47.498000000000005,
#   'lon': -121.756,
#   'alt_name': 'Exit 32 Little Si'},
#  {'name': 'Index',
#   'lat': 47.825,
#   'lon': -121.56200000000001,
#   'alt_name': 'Index'},
#  {'name': 'Frenchman Coulee, AKA Vantage',
#   'lat': 47.025,
#   'lon': -119.969,
#   'alt_name': 'Frenchman Coulee, AKA Vantage'},
#  {'name': 'Tieton River',
#   'lat': 46.684,
#   'lon': -120.958,
#   'alt_name': 'Tieton River'},
#  {'name': 'The New River Gorge',
#   'lat': 38.071999999999996,
#   'lon': -81.081,
#   'alt_name': 'The New River Gorge'},
#  {'name': 'Seneca Rocks',
#   'lat': 38.834,
#   'lon': -79.366,
#   'alt_name': 'Seneca Rocks'},
#  {'name': 'Summersville (Gauley River) Area',
#   'lat': 38.236,
#   'lon': -80.855,
#   'alt_name': 'Summersville (Gauley River) Area'},
#  {'name': "Devil's Lake",
#   'lat': 43.417,
#   'lon': -89.73200000000001,
#   'alt_name': "Devil's Lake"},
#  {'name': 'Governor Dodge State Park',
#   'lat': 43.027,
#   'lon': -90.104,
#   'alt_name': 'Governor Dodge State Park'},
#  {'name': "Devil's Lake Bouldering",
#   'lat': 43.415,
#   'lon': -89.73200000000001,
#   'alt_name': "Devil's Lake Bouldering"},
#  {'name': 'Devils Tower',
#   'lat': 44.59,
#   'lon': -104.71700000000001,
#   'alt_name': 'Devils Tower'},
#  {'name': 'Vedauwoo',
#   'lat': 41.185,
#   'lon': -105.37799999999999,
#   'alt_name': 'Vedauwoo'},
#  {'name': 'Grand Teton National Park',
#   'lat': 43.74100000000001,
#   'lon': -110.803,
#   'alt_name': 'Grand Teton National Park'},
#  {'name': 'Wind River Range',
#   'lat': 42.755,
#   'lon': -109.204,
#   'alt_name': 'Wind River Range'},
#  {'name': 'Sinks Canyon',
#   'lat': 42.739,
#   'lon': -108.83,
#   'alt_name': 'Sinks Canyon'},
#  {'name': 'Rock Springs Buttress',
#   'lat': 43.588,
#   'lon': -110.87,
#   'alt_name': 'Rock Springs Buttress'}]

# %%
#hiking api - Method: getTrails
i=1
for ea in range(0,len(cities_list)):
#     print(cities_list[ea]['lat'])
#     print(cities_list[ea]['lon'])
    lat = cities_list[ea]['lat']
    lon = cities_list[ea]['lon']
    max_distance = 50
    max_results = 500
    url = f'https://www.hikingproject.com/data/get-trails?lat={lat}&lon={lon}&maxDistance={max_distance}&maxResults={max_results}&key={hike_api}'
    response = requests.get(url).json()
    response_df = pd.DataFrame(response['trails'])
    response_df['city']=cities_list[ea]['name']
    response_df.to_sql(name = 'trails', con = engine, if_exists='append', index=False)
    print(f"{i}/{len(cities)}")
    i=i+1
# Out:
# 1/117
# 2/117
# 3/117
# 4/117
# 5/117
# 6/117
# 7/117
# 8/117
# 9/117
# 10/117
# 11/117
# 12/117
# 13/117
# 14/117
# 15/117
# 16/117
# 17/117
# 18/117
# 19/117
# 20/117
# 21/117
# 22/117
# 23/117
# 24/117
# 25/117
# 26/117
# 27/117
# 28/117
# 29/117
# 30/117
# 31/117
# 32/117
# 33/117
# 34/117
# 35/117
# 36/117
# 37/117
# 38/117
# 39/117
# 40/117
# 41/117
# 42/117
# 43/117
# 44/117
# 45/117
# 46/117
# 47/117
# 48/117
# 49/117
# 50/117
# 51/117
# 52/117
# 53/117
# 54/117
# 55/117
# 56/117
# 57/117
# 58/117
# 59/117
# 60/117
# 61/117
# 62/117
# 63/117
# 64/117
# 65/117
# 66/117
# 67/117
# 68/117
# 69/117
# 70/117
# 71/117
# 72/117
# 73/117
# 74/117
# 75/117
# 76/117
# 77/117
# 78/117
# 79/117
# 80/117
# 81/117
# 82/117
# 83/117
# 84/117
# 85/117
# 86/117
# 87/117
# 88/117
# 89/117
# 90/117
# 91/117
# 92/117
# 93/117
# 94/117
# 95/117
# 96/117
# 97/117
# 98/117
# 99/117
# 100/117
# 101/117
# 102/117
# 103/117
# 104/117
# 105/117
# 106/117
# 107/117
# 108/117
# 109/117
# 110/117
# 111/117
# 112/117
# 113/117
# 114/117
# 115/117
# 116/117
# 117/117

# %%
#hiking api - Method: getTrails
lat = 40.0274
lon = -105.2519
max_distance = 50
url = f'https://www.hikingproject.com/data/get-trails?lat={lat}&lon={lon}&maxDistance={max_distance}&key={hike_api}'
response = requests.get(url).json()

# %%
#climb api - Method: getRoutesForLatLong
lat = 40.0274
lon = -105.2519
max_distance = 50
min_diff = '5.6'
max_diff = '5.10'
url = f'https://www.hikingproject.com/data/get-trails?lat={lat}&lon={lon}&maxDistance={max_distance}&key={hike_api}'
f'https://www.mountainproject.com/data/get-routes-for-lat-lon?lat={lat}&lon={lon}&maxDistance={max_distance}&minDiff={min_diff}&maxDiff={max_diff}&key={mtn_api}'
response = requests.get(url).json()
response
# Out:
# {'trails': [{'id': 7006663,
#    'name': 'Monarch Lake to Crater Lake',
#    'type': 'Recommended Route',
#    'summary': 'Gorgeous scenery with waterfalls and wildflowers ending at a breathtaking cirque and glacier lake.',
#    'difficulty': 'blueBlack',
#    'stars': 4.9,
#    'starVotes': 85,
#    'location': 'Granby, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006663/monarch-lake-to-crater-lake',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7002724_sqsmall_1554227142.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7002724_small_1554227142.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7002724_smallMed_1554227142.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7002724_medium_1554227142.jpg',
#    'length': 14.9,
#    'ascent': 2017,
#    'descent': -2017,
#    'high': 10343,
#    'low': 8350,
#    'longitude': -105.7463,
#    'latitude': 40.1108,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Fallen Trees',
#    'conditionDate': '2020-10-10 21:37:09'},
#   {'id': 7011192,
#    'name': 'Boulder Skyline Traverse',
#    'type': 'Recommended Route',
#    'summary': 'The classic long mountain route in Boulder.',
#    'difficulty': 'black',
#    'stars': 4.7,
#    'starVotes': 93,
#    'location': 'Superior, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7011192/boulder-skyline-traverse',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7039883_sqsmall_1555092747.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7039883_small_1555092747.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7039883_smallMed_1555092747.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7039883_medium_1555092747.jpg',
#    'length': 17.3,
#    'ascent': 5446,
#    'descent': -5524,
#    'high': 8446,
#    'low': 5424,
#    'longitude': -105.2582,
#    'latitude': 39.9388,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-09-16 14:37:11'},
#   {'id': 7006795,
#    'name': 'High Lonesome Loop',
#    'type': 'Recommended Route',
#    'summary': 'A backcountry trail providing the best of high alpine hiking, with stunning views along the Divide.',
#    'difficulty': 'black',
#    'stars': 4.9,
#    'starVotes': 80,
#    'location': 'Nederland, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006795/high-lonesome-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7034581_sqsmall_1555000565.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7034581_small_1555000565.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7034581_smallMed_1555000565.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7034581_medium_1555000565.jpg',
#    'length': 15.7,
#    'ascent': 3162,
#    'descent': -3162,
#    'high': 12035,
#    'low': 8988,
#    'longitude': -105.5951,
#    'latitude': 39.9516,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Forest closed!',
#    'conditionDate': '2020-11-07 22:01:05'},
#   {'id': 7002175,
#    'name': 'Sky Pond',
#    'type': 'Recommended Route',
#    'summary': 'Sky Pond is in a deep valley carved by Taylor Glacier and capped by Taylor and Powell Peak.',
#    'difficulty': 'black',
#    'stars': 4.9,
#    'starVotes': 269,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002175/sky-pond',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7053480_sqsmall_1555703487.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7053480_small_1555703487.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7053480_smallMed_1555703487.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7053480_medium_1555703487.jpg',
#    'length': 8.3,
#    'ascent': 2000,
#    'descent': -1999,
#    'high': 11014,
#    'low': 9162,
#    'longitude': -105.6403,
#    'latitude': 40.3105,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Closed due to east troublesome fire',
#    'conditionDate': '2020-11-10 22:43:07'},
#   {'id': 7000130,
#    'name': 'Bear Peak Out and Back',
#    'type': 'Recommended Route',
#    'summary': 'A must-do hike for Boulder locals and visitors alike!',
#    'difficulty': 'black',
#    'stars': 4.6,
#    'starVotes': 123,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000130/bear-peak-out-and-back',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7005382_sqsmall_1554312030.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7005382_small_1554312030.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7005382_smallMed_1554312030.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7005382_medium_1554312030.jpg',
#    'length': 5.7,
#    'ascent': 2541,
#    'descent': -2540,
#    'high': 8342,
#    'low': 6103,
#    'longitude': -105.2755,
#    'latitude': 39.9787,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2020-10-22 13:00:06'},
#   {'id': 7000276,
#    'name': 'Emerald Lake',
#    'type': 'Recommended Route',
#    'summary': 'An easy to moderate out and back that culminates at views of Emerald Lake.',
#    'difficulty': 'blue',
#    'stars': 4.7,
#    'starVotes': 306,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000276/emerald-lake',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7017842_sqsmall_1554829871.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7017842_small_1554829871.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7017842_smallMed_1554829871.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7017842_medium_1554829871.jpg',
#    'length': 3.3,
#    'ascent': 661,
#    'descent': -651,
#    'high': 10104,
#    'low': 9476,
#    'longitude': -105.6457,
#    'latitude': 40.312,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Closed due to east troublesome fire',
#    'conditionDate': '2020-11-10 22:43:07'},
#   {'id': 7000487,
#    'name': 'Longs Peak - Keyhole Route',
#    'type': 'Recommended Route',
#    'summary': 'A beautiful and rewarding route to the summit of an iconic Colorado peak.',
#    'difficulty': 'black',
#    'stars': 4.8,
#    'starVotes': 99,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000487/longs-peak-keyhole-route',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7037747_sqsmall_1555086694.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7037747_small_1555086694.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7037747_smallMed_1555086694.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7037747_medium_1555086694.jpg',
#    'length': 14,
#    'ascent': 5241,
#    'descent': -5231,
#    'high': 14196,
#    'low': 9404,
#    'longitude': -105.5566,
#    'latitude': 40.2722,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2020-10-25 20:20:06'},
#   {'id': 7004226,
#    'name': "Sunshine Lion's Lair Loop",
#    'type': 'Recommended Route',
#    'summary': 'Great Mount Sanitas views are the reward for this gentler loop in Sunshine Canyon.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 119,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004226/sunshine-lions-lair-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7039883_sqsmall_1555092747.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7039883_small_1555092747.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7039883_smallMed_1555092747.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7039883_medium_1555092747.jpg',
#    'length': 5.3,
#    'ascent': 1261,
#    'descent': -1282,
#    'high': 6800,
#    'low': 5530,
#    'longitude': -105.2979,
#    'latitude': 40.02,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-10-19 15:37:52'},
#   {'id': 7003636,
#    'name': 'Grays and Torreys Peaks',
#    'type': 'Recommended Route',
#    'summary': 'Summit two 14ers on the Continental Divide along an alpine lollipop loop close to Denver',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 117,
#    'location': 'Georgetown, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7003636/grays-and-torreys-peaks',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7065315_sqsmall_1575696682.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7065315_small_1575696682.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7065315_smallMed_1575696682.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7065315_medium_1575696682.jpg',
#    'length': 8.3,
#    'ascent': 3479,
#    'descent': -3466,
#    'high': 14246,
#    'low': 11242,
#    'longitude': -105.7846,
#    'latitude': 39.6609,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-10-04 15:44:56'},
#   {'id': 7001041,
#    'name': 'Chasm Lake',
#    'type': 'Recommended Route',
#    'summary': 'A must-do RMNP hike that leads to and from an incredible alpine lake.',
#    'difficulty': 'black',
#    'stars': 4.7,
#    'starVotes': 89,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001041/chasm-lake',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7000727_sqsmall_1554159596.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7000727_small_1554159596.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7000727_smallMed_1554159596.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7000727_medium_1554159596.jpg',
#    'length': 8.2,
#    'ascent': 2766,
#    'descent': -2766,
#    'high': 11675,
#    'low': 9430,
#    'longitude': -105.5566,
#    'latitude': 40.2716,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-09-25 11:55:06'}],
#  'success': 1}

# %%
from flask import Flask, render_template, redirect, jsonify
from sqlalchemy import create_engine
import sqlalchemy as db

connection_string = "postgres:sealab2021@dvgroup1.c0yvlavqskus.us-west-2.rds.amazonaws.com:5432/project2"
engine = db.create_engine(f'postgresql://{connection_string}')
connection = engine.connect()
metadata = db.MetaData()

# %%
table = db.Table('trails', metadata, autoload = True, autoload_with=engine)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-95df0cb34d58> in <module>
# ----> 1 for ea in table.columns():
#       2     print(ea)
#
# TypeError: 'ImmutableColumnCollection' object is not callable
